# %%
# import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns

# %% [raw]
# #Problem Statement: We are going to solve a binary categorical problem
# In which we need to build a model, using age as an input ,
# on the basis
# of this age factor we want predict whether
# that person will BUY and insurance or not

# %%
# When we try to formulate any problem statement
# We need to understand KPI's
# Key performance Indicators

# %%
df = pd.read_csv('insurance.csv')
df
# Out:
#     age  braught_insurance
# 0    22                  0
# 1    25                  0
# 2    47                  1
# 3    52                  0
# 4    46                  1
# 5    56                  1
# 6    55                  0
# 7    60                  1
# 8    62                  1
# 9    61                  1
# 10   18                  0
# 11   28                  0
# 12   27                  0
# 13   29                  0
# 14   49                  1
# 15   55                  1
# 16   25                  1
# 17   58                  1
# 18   19                  0
# 19   18                  0
# 20   21                  0
# 21   26                  0
# 22   40                  1
# 23   45                  1
# 24   50                  1
# 25   54                  1
# 26   23                  0

# %%
df.columns
# Out:
# Index(['age', 'braught_insurance'], dtype='object')

# %%
#check the relastionship using scatter plot
sns.scatterplot(x='age',y='braught_insurance',data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='braught_insurance'>

# %% [raw]
# findings: Data is as per assumptions of Logistic regression
#     Forms S curve
#     Binary format in Dependant variable

# %% [raw]
# #without splitting data will procees for training of model

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
#Create input + output
X = df[['age']]
y =  df.braught_insurance

# %%
LR.fit(X,y)
# Out:
# LogisticRegression()

# %% [markdown]
# # Model Testing

# %%
age = [[34]]
LR.predict(age)
# Out:
# array([0], dtype=int64)

# %%
LR.predict([[65]])
# Out:
# array([1], dtype=int64)

# %%
#Logistic regression is a Probablistic model
# based on Probablity??? HOW>>>

# %% [raw]
# Actual formula we use is:
#                 1
# y_pred = --------------
#            1  + e^(-y)
# y_pred is nothing but a probablity

# %%
x= 65
m = LR.coef_
c = LR.intercept_

# %%
from math import e
e
# Out:
# 2.718281828459045

# %% [markdown]
# ### check y now..... y=mx+c

# %%
y =m*x + c
y
# Out:
# array([[3.54246691]])

# %% [markdown]
# ## check y_pred now

# %%
1/ 1+e**(-(y)) #when ur x=65
# Out:
# array([[1.02894184]])

# %%
1/ (1+e**(-(m*65+c)))
# Out:
# array([[0.97187223]])

# %%
#check for rakhesh age=34
1/ (1+e**(-(m*34+c)))
# probablity is below 0.5 hence Rakesh is not going to Buy an insurance
# Out:
# array([[0.34142134]])

# %%
age = int(input('Enter your age:'))
prob = 1/ (1+e**(-(m*age+c)))
if prob > 0.5:
    print('A person with age',age,'is going to Buy an insurance')
else:
    print('A person with age',age,'is NOT going to Buy an insurance')
# Out:
# Enter your age:18
# A person with age 18 is NOT going to Buy an insurance
