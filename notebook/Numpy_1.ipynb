# %% [markdown]
# # Numpy

# %%
# import numpy
import numpy

# %%
numpy
# Out:
# <module 'numpy' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\numpy\\__init__.py'>

# %%
print(dir(numpy))
# Out:
# ['ALLOW_THREADS', 'AxisError', 'BUFSIZE', 'Bytes0', 'CLIP', 'ComplexWarning', 'DataSource', 'Datetime64', 'ERR_CALL', 'ERR_DEFAULT', 'ERR_IGNORE', 'ERR_LOG', 'ERR_PRINT', 'ERR_RAISE', 'ERR_WARN', 'FLOATING_POINT_SUPPORT', 'FPE_DIVIDEBYZERO', 'FPE_INVALID', 'FPE_OVERFLOW', 'FPE_UNDERFLOW', 'False_', 'Inf', 'Infinity', 'MAXDIMS', 'MAY_SHARE_BOUNDS', 'MAY_SHARE_EXACT', 'MachAr', 'ModuleDeprecationWarning', 'NAN', 'NINF', 'NZERO', 'NaN', 'PINF', 'PZERO', 'RAISE', 'RankWarning', 'SHIFT_DIVIDEBYZERO', 'SHIFT_INVALID', 'SHIFT_OVERFLOW', 'SHIFT_UNDERFLOW', 'ScalarType', 'Str0', 'Tester', 'TooHardError', 'True_', 'UFUNC_BUFSIZE_DEFAULT', 'UFUNC_PYVALS_NAME', 'Uint64', 'VisibleDeprecationWarning', 'WRAP', '_NoValue', '_UFUNC_API', '__NUMPY_SETUP__', '__all__', '__builtins__', '__cached__', '__config__', '__deprecated_attrs__', '__dir__', '__doc__', '__expired_functions__', '__file__', '__getattr__', '__git_revision__', '__loader__', '__mkl_version__', '__name__', '__package__', '__path__', '__
# ...

# %% [markdown]
# ### background dat structure is array

# %%
a = numpy.array([100,101,102,103,104])
a
# Out:
# array([100, 101, 102, 103, 104])

# %%
a[2]
# Out:
# 102

# %%
a[-1]
# Out:
# 104

# %%
a[0]
# Out:
# 100

# %%
a
# Out:
# array([100, 101, 102, 103, 104])

# %%
# reverse array
a[::-1]
# Out:
# array([104, 103, 102, 101, 100])

# %%
# what is typee of numpy array?
type(a)
# Out:
# numpy.ndarray

# %% [markdown]
# #### ndarray:N dimensional array

# %%
a
# Out:
# array([100, 101, 102, 103, 104])

# %%
b = [100, 101, 102, 103, 104]
b
# Out:
# [100, 101, 102, 103, 104]

# %% [markdown]
# ### q. what difference between list and numpy array

# %%
#numpy performs elementwise operations
print(a)
a + 100
# Out:
# [100 101 102 103 104]
# array([200, 201, 202, 203, 204])

# %%
print(b)
b + 100
# in case of list its not possible
# Out:
# [100, 101, 102, 103, 104]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11048/2102116790.py in <module>
#       1 print(b)
# ----> 2 b + 100
#
# TypeError: can only concatenate list (not "int") to list

# %%
# memory required
a.__sizeof__()
# Out:
# 124

# %%
b.__sizeof__()
# Out:
# 104

# %%
# Assignment:
# Q. what is difference between array and numpy array
# Q. what is difference between array and list

# %%
import array

# %% [markdown]
# # Structure of numpy array

# %%
help(numpy.array)
# Out:
# Help on built-in function array in module numpy:
#
# array(...)
#     array(object, dtype=None, *, copy=True, order='K', subok=False, ndmin=0,
#           like=None)
#
#     Create an array.
#
#     Parameters
#     ----------
#     object : array_like
#         An array, any object exposing the array interface, an object whose
#         __array__ method returns an array, or any (nested) sequence.
#     dtype : data-type, optional
#         The desired data-type for the array.  If not given, then the type will
#         be determined as the minimum type required to hold the objects in the
#         sequence.
#     copy : bool, optional
#         If true (default), then the object is copied.  Otherwise, a copy will
#         only be made if __array__ returns a copy, if obj is a nested sequence,
#         or if a copy is needed to satisfy any of the other requirements
#         (`dtype`, `order`, etc.).
#     order : {'K', 'A', 'C', 'F'}, optional
# ...

# %%
numpy.array?

# %%
numpy.array #use shift+tab to get information abt any method or attribute

# %% [markdown]
# # numpy.array(object,dtype)

# %%
import numpy as np

# %%
np.array(100)
# Out:
# array(100)

# %%
np.array('python7')
# Out:
# array('python7', dtype='<U7')

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
np.array(range(101,110))
# Out:
# array([101, 102, 103, 104, 105, 106, 107, 108, 109])

# %%
np.array(True)
# Out:
# array(True)

# %%
np.array([True,False,True])
# Out:
# array([ True, False,  True])

# %% [markdown]
# ## dtype: data type

# %%
np.array(10).dtype
# Out:
# dtype('int32')

# %%
np.array(True).dtype
# Out:
# dtype('bool')

# %%
#8 bit 1 byte
# 32 bit 4 bytes

# %%
np.array(12.55)
# Out:
# array(12.55)

# %%
np.array(12.55).dtype
# Out:
# dtype('float64')

# %%
np.array(12.55).itemsize #gives output in bytes
# Out:
# 8

# %%
np.array([12,34,56,67,89]).itemsize
# Out:
# 4

# %% [markdown]
# # Dimenstions of numpy array

# %%
a
# Out:
# array([100, 101, 102, 103, 104])

# %%
#check dim of array
a.ndim
# Out:
# 1

# %%
#lets create 2D array
x = np.array([[1,2],[3,4]])
x
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
x.ndim
# Out:
# 2

# %%
#check shape(rows,columns)
x.shape
# Out:
# (2, 2)

# %%
y = np.array([[1,2,10],[3,4,20],[6,7,8]])
y
# Out:
# array([[ 1,  2, 10],
#        [ 3,  4, 20],
#        [ 6,  7,  8]])

# %%
y.ndim
# Out:
# 2

# %%
y.shape
# Out:
# (3, 3)

# %% [markdown]
# ## create a 3D array

# %%
z = np.array([[[1,2],[3,4]],
          [[6,7],[8,9]]])
z
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[6, 7],
#         [8, 9]]])

# %%
z.ndim
# Out:
# 3

# %%
z.shape #block,row,column
# Out:
# (2, 2, 2)

# %%
#  Summary
"""
1D: collection of objects one after another, example a
2D: Collection of 1D array example x
3D: collection of 2D array eXAMPLE: z
"""

# %%
a
# Out:
# array([100, 101, 102, 103, 104])

# %%
list(a)
# Out:
# [100, 101, 102, 103, 104]

# %%
x
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
list(x)
# Out:
# [array([1, 2]), array([3, 4])]

# %%
z
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[6, 7],
#         [8, 9]]])

# %%
list(z)
# Out:
# [array([[1, 2],
#         [3, 4]]),
#  array([[6, 7],
#         [8, 9]])]

# %%
z.shape
# Out:
# (2, 2, 2)
