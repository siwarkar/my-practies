# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('batch_19.xlsx')
df.head(2)
# Out:
#    Sr. No           Name   Place  Post  Salary    Code  Age
# 0       1  Akshay Bankar     Pune   DS   67000  AK-102   24
# 1       2    Arati Banne  Solapur   SE   56000  AB-304   20

# %%
#Fetch a record on DS using a groupby
df.groupby('Post').get_group('DS')
# Out:
#    Sr. No             Name  Place  Post  Salary    Code  Age
# 0       1    Akshay Bankar    Pune   DS   67000  AK-102   24
# 4       5  Harshala Gondal  Sangli   DS   45000  HG-232   40

# %%
#without groupby
df.query('Post == "DS"')
# Out:
#    Sr. No             Name  Place  Post  Salary    Code  Age
# 0       1    Akshay Bankar    Pune   DS   67000  AK-102   24
# 4       5  Harshala Gondal  Sangli   DS   45000  HG-232   40

# %%
# Sort the data wrt Age
df.sort_values(by='Age')
# Out:
#     Sr. No             Name    Place     Post  Salary    Code  Age
# 1        2      Arati Banne   Solapur      SE   56000  AB-304   20
# 8        9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102   22
# 0        1    Akshay Bankar      Pune      DS   67000  AK-102   24
# 5        6     Kuldip Muley      Beed     CEO  120000  KM-333   25
# 2        3     Dipak Sawant  Kolhapur   Admin   78000  DS-100   28
# 7        8     Umesh Thorat      Pune      SE   67000  UT-102   28
# 10      11    Shital Shelar     Karad  Tester   80000  SS-222   33
# 9       10    Supriya Gurav      Pune      SE   90000  SG-100   35
# 4        5  Harshala Gondal    Sangli      DS   45000  HG-232   40
# 6        7    Piyush Sawant    Mumbai      SE   89000      PS   59
# 3        4    Ganesh Rakate    Sangli      HR   80000  GR-450   63

# %%
df.Age.sort_values()
# Out:
# 1     20
# 8     22
# 0     24
# 5     25
# 2     28
# 7     28
# 10    33
# 9     35
# 4     40
# 6     59
# 3     63
# Name: Age, dtype: int64

# %%
# Fetch Post and Salary of an employee from Solapur
ans = df.groupby('Place ').get_group('Solapur')
ans[['Post','Salary']]
# Out:
#   Post  Salary
# 1   SE   56000

# %%
ans2 = df[df['Place '] == 'Solapur']
ans2[['Post','Salary']]
# Out:
#   Post  Salary
# 1   SE   56000

# %%
df
# Out:
#     Sr. No             Name    Place     Post  Salary    Code  Age
# 0        1    Akshay Bankar      Pune      DS   67000  AK-102   24
# 1        2      Arati Banne   Solapur      SE   56000  AB-304   20
# 2        3     Dipak Sawant  Kolhapur   Admin   78000  DS-100   28
# 3        4    Ganesh Rakate    Sangli      HR   80000  GR-450   63
# 4        5  Harshala Gondal    Sangli      DS   45000  HG-232   40
# 5        6     Kuldip Muley      Beed     CEO  120000  KM-333   25
# 6        7    Piyush Sawant    Mumbai      SE   89000      PS   59
# 7        8     Umesh Thorat      Pune      SE   67000  UT-102   28
# 8        9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102   22
# 9       10    Supriya Gurav      Pune      SE   90000  SG-100   35
# 10      11    Shital Shelar     Karad  Tester   80000  SS-222   33

# %%
df[df.Post.str.startswith('DS')]
# Out:
#    Sr. No             Name  Place  Post  Salary    Code  Age
# 0       1    Akshay Bankar    Pune   DS   67000  AK-102   24
# 4       5  Harshala Gondal  Sangli   DS   45000  HG-232   40

# %%
# FEtch Umesh record using query
df.query('Name == "Umesh Thorat"')
# Out:
#    Sr. No          Name Place  Post  Salary    Code  Age
# 7       8  Umesh Thorat   Pune   SE   67000  UT-102   28

# %%
# Fetch Min and Max salary for each Post with employee details
df.groupby('Post').agg([min,max])
# Out:
#        Sr. No               Name                     Place             Salary  \
#           min max            min              max       min       max     min
# Post
# Admin       3   3   Dipak Sawant     Dipak Sawant  Kolhapur  Kolhapur   78000
# CEO         6   6   Kuldip Muley     Kuldip Muley      Beed      Beed  120000
# DS          1   5  Akshay Bankar  Harshala Gondal      Pune    Sangli   45000
# HR          4   4  Ganesh Rakate    Ganesh Rakate    Sangli    Sangli   80000
# SE          2  10    Arati Banne     Umesh Thorat    Mumbai   Solapur   56000
# Tester      9  11  Shital Shelar    Vaibhav Ladge     Karad  Kolhapur   80000
#
#                   Code         Age
#            max     min     max min max
# Post
# Admin    78000  DS-100  DS-100  28  28
# CEO     120000  KM-333  KM-333  25  25
# DS       67000  AK-102  HG-232  24  40
# HR       80000  GR-450  GR-450  63  63
# SE       90000  AB-304  UT-102  20  59
# Tester   87000  SS-222  VL-102  22  33

# %%
# Fetching random 3 rows
random= df.sample(3)
random
# Out:
#     Sr. No           Name    Place     Post  Salary    Code  Age
# 8        9  Vaibhav Ladge  Kolhapur  Tester   87000  VL-102   22
# 1        2    Arati Banne   Solapur      SE   56000  AB-304   20
# 10      11  Shital Shelar     Karad  Tester   80000  SS-222   33

# %%
random.index
# Out:
# Int64Index([8, 1, 10], dtype='int64')

# %%
# delete random rows
df.drop(index=random.index)
# Out:
#    Sr. No             Name    Place    Post  Salary    Code  Age
# 0       1    Akshay Bankar      Pune     DS   67000  AK-102   24
# 2       3     Dipak Sawant  Kolhapur  Admin   78000  DS-100   28
# 3       4    Ganesh Rakate    Sangli     HR   80000  GR-450   63
# 4       5  Harshala Gondal    Sangli     DS   45000  HG-232   40
# 5       6     Kuldip Muley      Beed    CEO  120000  KM-333   25
# 6       7    Piyush Sawant    Mumbai     SE   89000      PS   59
# 7       8     Umesh Thorat      Pune     SE   67000  UT-102   28
# 9      10    Supriya Gurav      Pune     SE   90000  SG-100   35

# %%
# reverse rows and columns
#df[::-1] #reverse the rows
df.loc[::-1,::-1]
# Out:
#     Age    Code  Salary    Post    Place              Name  Sr. No
# 10   33  SS-222   80000  Tester     Karad    Shital Shelar      11
# 9    35  SG-100   90000      SE      Pune    Supriya Gurav      10
# 8    22  VL-102   87000  Tester  Kolhapur    Vaibhav Ladge       9
# 7    28  UT-102   67000      SE      Pune     Umesh Thorat       8
# 6    59      PS   89000      SE    Mumbai    Piyush Sawant       7
# 5    25  KM-333  120000     CEO      Beed     Kuldip Muley       6
# 4    40  HG-232   45000      DS    Sangli  Harshala Gondal       5
# 3    63  GR-450   80000      HR    Sangli    Ganesh Rakate       4
# 2    28  DS-100   78000   Admin  Kolhapur     Dipak Sawant       3
# 1    20  AB-304   56000      SE   Solapur      Arati Banne       2
# 0    24  AK-102   67000      DS      Pune    Akshay Bankar       1

# %%
# fetch record below avg salary
mn = df.Salary.mean()
mn
# Out:
# 78090.90909090909

# %%
df[df.Salary < mn]
# Out:
#    Sr. No             Name    Place    Post  Salary    Code  Age
# 0       1    Akshay Bankar      Pune     DS   67000  AK-102   24
# 1       2      Arati Banne   Solapur     SE   56000  AB-304   20
# 2       3     Dipak Sawant  Kolhapur  Admin   78000  DS-100   28
# 4       5  Harshala Gondal    Sangli     DS   45000  HG-232   40
# 7       8     Umesh Thorat      Pune     SE   67000  UT-102   28

# %%
# Add a row with Name, Age , Salary
d = {'Name':'Maulaali','Age':32,'Salary':67000}
d
# Out:
# {'Name': 'Maulaali', 'Age': 32, 'Salary': 67000}

# %%
df.append(d,ignore_index=True)
# Out:
#     Sr. No             Name    Place     Post  Salary    Code  Age
# 0      1.0    Akshay Bankar      Pune      DS   67000  AK-102   24
# 1      2.0      Arati Banne   Solapur      SE   56000  AB-304   20
# 2      3.0     Dipak Sawant  Kolhapur   Admin   78000  DS-100   28
# 3      4.0    Ganesh Rakate    Sangli      HR   80000  GR-450   63
# 4      5.0  Harshala Gondal    Sangli      DS   45000  HG-232   40
# 5      6.0     Kuldip Muley      Beed     CEO  120000  KM-333   25
# 6      7.0    Piyush Sawant    Mumbai      SE   89000      PS   59
# 7      8.0     Umesh Thorat      Pune      SE   67000  UT-102   28
# 8      9.0    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102   22
# 9     10.0    Supriya Gurav      Pune      SE   90000  SG-100   35
# 10    11.0    Shital Shelar     Karad  Tester   80000  SS-222   33
# 11     NaN         Maulaali       NaN     NaN   67000     NaN   32

# %%
df
# Out:
#     Sr. No             Name    Place     Post  Salary    Code  Age
# 0        1    Akshay Bankar      Pune      DS   67000  AK-102   24
# 1        2      Arati Banne   Solapur      SE   56000  AB-304   20
# 2        3     Dipak Sawant  Kolhapur   Admin   78000  DS-100   28
# 3        4    Ganesh Rakate    Sangli      HR   80000  GR-450   63
# 4        5  Harshala Gondal    Sangli      DS   45000  HG-232   40
# 5        6     Kuldip Muley      Beed     CEO  120000  KM-333   25
# 6        7    Piyush Sawant    Mumbai      SE   89000      PS   59
# 7        8     Umesh Thorat      Pune      SE   67000  UT-102   28
# 8        9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102   22
# 9       10    Supriya Gurav      Pune      SE   90000  SG-100   35
# 10      11    Shital Shelar     Karad  Tester   80000  SS-222   33

# %%
df.values
# Out:
# array([[1, 'Akshay Bankar', 'Pune', 'DS', 67000, 'AK-102', 24],
#        [2, 'Arati Banne', 'Solapur', 'SE', 56000, 'AB-304', 20],
#        [3, 'Dipak Sawant', 'Kolhapur', 'Admin', 78000, 'DS-100', 28],
#        [4, 'Ganesh Rakate', 'Sangli', 'HR', 80000, 'GR-450', 63],
#        [5, 'Harshala Gondal', 'Sangli', 'DS', 45000, 'HG-232', 40],
#        [6, 'Kuldip Muley', 'Beed', 'CEO', 120000, 'KM-333', 25],
#        [7, 'Piyush Sawant', 'Mumbai', 'SE', 89000, 'PS', 59],
#        [8, 'Umesh Thorat', 'Pune', 'SE', 67000, 'UT-102', 28],
#        [9, 'Vaibhav Ladge', 'Kolhapur', 'Tester', 87000, 'VL-102', 22],
#        [10, 'Supriya Gurav', 'Pune', 'SE', 90000, 'SG-100', 35],
#        [11, 'Shital Shelar', 'Karad', 'Tester', 80000, 'SS-222', 33]],
#       dtype=object)

# %%
pd.DataFrame(np.insert(df.values,4,[101,'Jones','Dubai','Tester',90000,'UAE-100',34],axis = 0), columns = df.columns)
# Out:
#    Sr. No             Name    Place     Post  Salary     Code Age
# 0       1    Akshay Bankar      Pune      DS   67000   AK-102  24
# 1       2      Arati Banne   Solapur      SE   56000   AB-304  20
# 2       3     Dipak Sawant  Kolhapur   Admin   78000   DS-100  28
# 3       4    Ganesh Rakate    Sangli      HR   80000   GR-450  63
# 4     101            Jones     Dubai  Tester   90000  UAE-100  34
# 5       5  Harshala Gondal    Sangli      DS   45000   HG-232  40
# 6       6     Kuldip Muley      Beed     CEO  120000   KM-333  25
# 7       7    Piyush Sawant    Mumbai      SE   89000       PS  59
# 8       8     Umesh Thorat      Pune      SE   67000   UT-102  28
# 9       9    Vaibhav Ladge  Kolhapur  Tester   87000   VL-102  22
# 10     10    Supriya Gurav      Pune      SE   90000   SG-100  35
# 11     11    Shital Shelar     Karad  Tester   80000   SS-222  33

# %%
e = pd.DataFrame()
e.__sizeof__()
# Out:
# 0

# %%
d = pd.DataFrame(np.random.random((4,5)))
d
# Out:
#           0         1         2         3         4
# 0  0.277465  0.779753  0.297460  0.059841  0.167167
# 1  0.089723  0.859918  0.337614  0.554055  0.582489
# 2  0.419609  0.932432  0.498847  0.664213  0.798321
# 3  0.965610  0.171600  0.445822  0.947058  0.513537

# %%
d.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
type(d)
# Out:
# pandas.core.frame.DataFrame

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
# Remove duplicate rows
f = pd.DataFrame([[1,2],[1,2],[3,4]])
f
# Out:
#    0  1
# 0  1  2
# 1  1  2
# 2  3  4

# %%
f[f.duplicated()]
# Out:
#    0  1
# 1  1  2

# %%
f.drop_duplicates(ignore_index=True)
# Out:
#    0  1
# 0  1  2
# 1  3  4

# %%
# Remove duplicate columns
h = pd.DataFrame([[1,1],[1,1]],columns=['A','A'])
h
# Out:
#    A  A
# 0  1  1
# 1  1  1

# %%
# transpose
h.T
# Out:
#    0  1
# A  1  1
# A  1  1

# %%
h.T.duplicated()
# Out:
# A    False
# A     True
# dtype: bool

# %%
h.T.drop_duplicates()
# Out:
#    0  1
# A  1  1

# %%
# Drop duplicate column names

# %%
h
# Out:
#    A  A
# 0  1  1
# 1  1  1

# %%
np.unique(h.columns)
# Out:
# array(['A'], dtype=object)

# %%
h['A']
# Out:
#    A  A
# 0  1  1
# 1  1  1

# %%
ls = list(h.columns)
ls
# Out:
# ['A', 'A']

# %%
for i in h:
    if i in ls:
        print(h[i])
# Out:
#    A  A
# 0  1  1
# 1  1  1
#    A  A
# 0  1  1
# 1  1  1

# %%
h.pop('A')
# Out:
#    A  A
# 0  1  1
# 1  1  1

# %%
h
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1]

# %%
h
# Out:
#    A  A
# 0  1  1
# 1  1  1

# %%
# This function take a dataframe 
# as a parameter and returning list 
# of column names whose contents  
# are duplicates. 
def getDuplicateColumns(df): 
  
    # Create an empty set 
    duplicateColumnNames = set() 
      
    # Iterate through all the columns  
    # of dataframe 
    for x in range(df.shape[1]): 
          
        # Take column at xth index. 
        col = df.iloc[:, x] 
          
        # Iterate through all the columns in 
        # DataFrame from (x + 1)th index to 
        # last index 
        for y in range(x + 1, df.shape[1]): 
              
            # Take column at yth index. 
            otherCol = df.iloc[:, y] 
              
            # Check if two columns at x & y 
            # index are equal or not, 
            # if equal then adding  
            # to the set 
            if col.equals(otherCol): 
                duplicateColumnNames.add(df.columns.values[y]) 
                  
    # Return list of unique column names  
    # whose contents are duplicates. 
    return list(duplicateColumnNames) 
  
# Driver code 
if __name__ == "__main__" : 
  
    
  
    # Create a DataFrame object 
    df = h 
  
  
    # Get list of duplicate columns 
    duplicateColNames = getDuplicateColumns(df) 
  
    print('Duplicate Columns are :') 
        
    # Iterate through duplicate 
    # column names 
    for column in duplicateColNames : 
       print('Column Name : ', column)
# Out:
# Duplicate Columns are :
# Column Name :  A

# %%
df
# Out:
#    A  A
# 0  1  1
# 1  1  1

# %%
df.loc[:, ~df.columns.duplicated()]
# Out:
#    A
# 0  1
# 1  1
