# %% [markdown]
# ## Manipulation of DataFrame: How to add rows

# %%
import pandas as pd

# %%
# List of Tuples
students = [ ('jack', 34, 'Sydeny' , 'Australia') ,
             ('Riti', 30, 'Delhi' , 'India' ) ,
             ('Vikas', 31, 'Mumbai' , 'India' ) ,
             ('Neelu', 32, 'Bangalore' , 'India' ) ,
             ('John', 16, 'New York' , 'US') ,
             ('Mike', 17, 'las vegas' , 'US')  ]

# %%
students
# Out:
# [('jack', 34, 'Sydeny', 'Australia'),
#  ('Riti', 30, 'Delhi', 'India'),
#  ('Vikas', 31, 'Mumbai', 'India'),
#  ('Neelu', 32, 'Bangalore', 'India'),
#  ('John', 16, 'New York', 'US'),
#  ('Mike', 17, 'las vegas', 'US')]

# %%
#Create a DataFrame object
df = pd.DataFrame(students, columns = ['Name' , 'Age', 'City' , 'Country'], index=['a', 'b', 'c' , 'd' , 'e' , 'f']) 
df
# Out:
#     Name  Age       City    Country
# a   jack   34     Sydeny  Australia
# b   Riti   30      Delhi      India
# c  Vikas   31     Mumbai      India
# d  Neelu   32  Bangalore      India
# e   John   16   New York         US
# f   Mike   17  las vegas         US

# %% [markdown]
# ### using dataframe.append() and Dictionary

# %%
df.head(2)
# Out:
#    Name  Age    City    Country
# a  jack   34  Sydeny  Australia
# b  Riti   30   Delhi      India

# %%
# Pass the row elements as key value pairs to append() function 
modDfObj = df.append({'Name' : 'Sunil' , 'Age' : 22} )
modDfObj
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4032/948662361.py in <module>
#       1 # Pass the row elements as key value pairs to append() function
# ----> 2 modDfObj = df.append({'Name' : 'Sunil' , 'Age' : 22} )
#       3 modDfObj
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    8929             if isinstance(other, dict):
#    8930                 if not ignore_index:
# -> 8931                     raise TypeError("Can only append a dict if ignore_index=True")
#    8932                 other = Series(other)
#    8933             if other.name is None and not ignore_index:
#
# TypeError: Can only append a dict if ignore_index=True

# %%
modDfObj = df.append({'Name' : 'Sunil' , 'Age' : 22} , ignore_index=True)
modDfObj
# Out:
#     Name  Age       City    Country
# 0   jack   34     Sydeny  Australia
# 1   Riti   30      Delhi      India
# 2  Vikas   31     Mumbai      India
# 3  Neelu   32  Bangalore      India
# 4   John   16   New York         US
# 5   Mike   17  las vegas         US
# 6  Sunil   22        NaN        NaN

# %%
modDfObj = df.append({'Name' : 'Sunil' , 'Age' : 22,'pincode':123456} , ignore_index=True)
modDfObj
# Out:
#     Name  Age       City    Country   pincode
# 0   jack   34     Sydeny  Australia       NaN
# 1   Riti   30      Delhi      India       NaN
# 2  Vikas   31     Mumbai      India       NaN
# 3  Neelu   32  Bangalore      India       NaN
# 4   John   16   New York         US       NaN
# 5   Mike   17  las vegas         US       NaN
# 6  Sunil   22        NaN        NaN  123456.0

# %% [markdown]
# ### dataframe.append() and Series

# %%
s = pd.Series(['Raju', 21, 'Bangalore', 'India'],index=['Name','Age','City','Country'] )
s
# Out:
# Name            Raju
# Age               21
# City       Bangalore
# Country        India
# dtype: object

# %%
# Pass a series in append() to append a row in dataframe  ---#df.columns
modDfObj = df.append(s, 
                     ignore_index=True)
modDfObj
# Out:
#     Name  Age       City    Country
# 0   jack   34     Sydeny  Australia
# 1   Riti   30      Delhi      India
# 2  Vikas   31     Mumbai      India
# 3  Neelu   32  Bangalore      India
# 4   John   16   New York         US
# 5   Mike   17  las vegas         US
# 6   Raju   21  Bangalore      India

# %%
r = pd.Series(['Rohit',23,'Paris','US'])
r
# Out:
# 0    Rohit
# 1       23
# 2    Paris
# 3       US
# dtype: object

# %%
df.append(r,ignore_index=True)
# Out:
#     Name   Age       City    Country      0     1      2    3
# 0   jack  34.0     Sydeny  Australia    NaN   NaN    NaN  NaN
# 1   Riti  30.0      Delhi      India    NaN   NaN    NaN  NaN
# 2  Vikas  31.0     Mumbai      India    NaN   NaN    NaN  NaN
# 3  Neelu  32.0  Bangalore      India    NaN   NaN    NaN  NaN
# 4   John  16.0   New York         US    NaN   NaN    NaN  NaN
# 5   Mike  17.0  las vegas         US    NaN   NaN    NaN  NaN
# 6    NaN   NaN        NaN        NaN  Rohit  23.0  Paris   US

# %%
r = pd.Series(['Rohit',23,'Paris','US'],index=['Name','Age','City','Country'])
r
# Out:
# Name       Rohit
# Age           23
# City       Paris
# Country       US
# dtype: object

# %%
df.append(r,ignore_index=True)
# Out:
#     Name  Age       City    Country
# 0   jack   34     Sydeny  Australia
# 1   Riti   30      Delhi      India
# 2  Vikas   31     Mumbai      India
# 3  Neelu   32  Bangalore      India
# 4   John   16   New York         US
# 5   Mike   17  las vegas         US
# 6  Rohit   23      Paris         US

# %% [markdown]
# ### Add multiple rows

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Country'], dtype='object')

# %%
pd.Series(['Raju', 21, 'Bangalore', 'India'],index=df.columns)#['Name']
# Out:
# Name            Raju
# Age               21
# City       Bangalore
# Country        India
# dtype: object

# %%
# List of series  
listOfSeries = [pd.Series(['Raju', 21, 'Bangalore', 'India'], index=df.columns ) ,
                pd.Series(['Sam', 22, 'Tokyo', 'Japan'], index=df.columns ) ,
                pd.Series(['Rocky', 23, 'Las Vegas', 'US'], index=df.columns ) ]
listOfSeries
# Out:
# [Name            Raju
#  Age               21
#  City       Bangalore
#  Country        India
#  dtype: object,
#  Name         Sam
#  Age           22
#  City       Tokyo
#  Country    Japan
#  dtype: object,
#  Name           Rocky
#  Age               23
#  City       Las Vegas
#  Country           US
#  dtype: object]

# %%
# Pass a list of series to the append() to add multiple rows
modDfObj = df.append(listOfSeries)
modDfObj
# Out:
#     Name  Age       City    Country
# a   jack   34     Sydeny  Australia
# b   Riti   30      Delhi      India
# c  Vikas   31     Mumbai      India
# d  Neelu   32  Bangalore      India
# e   John   16   New York         US
# f   Mike   17  las vegas         US
# 0   Raju   21  Bangalore      India
# 1    Sam   22      Tokyo      Japan
# 2  Rocky   23  Las Vegas         US

# %%
df
# Out:
#     Name  Age       City    Country
# a   jack   34     Sydeny  Australia
# b   Riti   30      Delhi      India
# c  Vikas   31     Mumbai      India
# d  Neelu   32  Bangalore      India
# e   John   16   New York         US
# f   Mike   17  las vegas         US

# %%
modDfObj = df.append(listOfSeries , ignore_index=True)
modDfObj
# Out:
#     Name  Age       City    Country
# 0   jack   34     Sydeny  Australia
# 1   Riti   30      Delhi      India
# 2  Vikas   31     Mumbai      India
# 3  Neelu   32  Bangalore      India
# 4   John   16   New York         US
# 5   Mike   17  las vegas         US
# 6   Raju   21  Bangalore      India
# 7    Sam   22      Tokyo      Japan
# 8  Rocky   23  Las Vegas         US

# %% [markdown]
# ### Add a row from one dataframe to other datafram

# %%
# List of Tuples
students = [ ('Rahul', 22, 'Sydeny' , 'Australia') ,
             ('Parul', 23, 'Pune' , 'India')  ]
#Create a DataFrame object
df2 = pd.DataFrame(students, columns = df.columns, index=['a', 'b']) 
df2
# Out:
#     Name  Age    City    Country
# a  Rahul   22  Sydeny  Australia
# b  Parul   23    Pune      India

# %%
df
# Out:
#     Name  Age       City    Country
# a   jack   34     Sydeny  Australia
# b   Riti   30      Delhi      India
# c  Vikas   31     Mumbai      India
# d  Neelu   32  Bangalore      India
# e   John   16   New York         US
# f   Mike   17  las vegas         US

# %%
modDfobj = df.append(df2, ignore_index=True)
modDfobj
# Out:
#     Name  Age       City    Country
# 0   jack   34     Sydeny  Australia
# 1   Riti   30      Delhi      India
# 2  Vikas   31     Mumbai      India
# 3  Neelu   32  Bangalore      India
# 4   John   16   New York         US
# 5   Mike   17  las vegas         US
# 6  Rahul   22     Sydeny  Australia
# 7  Parul   23       Pune      India

# %%
df2.loc[['b'],:]
# Out:
#     Name  Age  City Country
# b  Parul   23  Pune   India

# %%
# add row at index b from dataframe df2 to dataframe dfObj
modDfobj = df.append(df2.loc['b'], ignore_index=True)
modDfobj
# Out:
#     Name  Age       City    Country
# 0   jack   34     Sydeny  Australia
# 1   Riti   30      Delhi      India
# 2  Vikas   31     Mumbai      India
# 3  Neelu   32  Bangalore      India
# 4   John   16   New York         US
# 5   Mike   17  las vegas         US
# 6  Parul   23       Pune      India

# %%
df2[:1]
# Out:
#     Name  Age    City    Country
# a  Rahul   22  Sydeny  Australia

# %%
#df2[:1]
#df2.head(1)
#df2.loc[['a']]
df2.iloc[[0]]
# Out:
#     Name  Age    City    Country
# a  Rahul   22  Sydeny  Australia

# %%
df.head(3).append(df2[:1],ignore_index=True)
# Out:
#     Name  Age    City    Country
# 0   jack   34  Sydeny  Australia
# 1   Riti   30   Delhi      India
# 2  Vikas   31  Mumbai      India
# 3  Rahul   22  Sydeny  Australia

# %%
df2[:1].append(df,ignore_index=True)

# %% [markdown]
# ## without append how to add rows

# %%
df
# Out:
#     Name  Age       City    Country
# a   jack   34     Sydeny  Australia
# b   Riti   30      Delhi      India
# c  Vikas   31     Mumbai      India
# d  Neelu   32  Bangalore      India
# e   John   16   New York         US
# f   Mike   17  las vegas         US

# %%
# Add a new row at index k with values provided in list
df.loc['g'] = ['Smriti', 26, 'Bangalore', 'India']
df
# Out:
#      Name  Age       City    Country
# a    jack   34     Sydeny  Australia
# b    Riti   30      Delhi      India
# c   Vikas   31     Mumbai      India
# d   Neelu   32  Bangalore      India
# e    John   16   New York         US
# f    Mike   17  las vegas         US
# g  Smriti   26  Bangalore      India

# %%
#if index is already present, at the same indeex
#if we want to add new data,then it will overwrite data
df.loc['e'] = ['Pravin', 26, 'Pune', 'India']
df
# Out:
#      Name  Age       City    Country
# a    jack   34     Sydeny  Australia
# b    Riti   30      Delhi      India
# c   Vikas   31     Mumbai      India
# d   Neelu   32  Bangalore      India
# e  Pravin   26       Pune      India
# f    Mike   17  las vegas         US
# g  Smriti   26  Bangalore      India

# %%
df.loc['e']
# Out:
# Name       Pravin
# Age            26
# City         Pune
# Country     India
# Name: e, dtype: object

# %%
df.iloc[2]
# Out:
# Name        Vikas
# Age            31
# City       Mumbai
# Country     India
# Name: c, dtype: object

# %%
# Add a new row at index position 2 with values provided in list
df.iloc[2] = ['Mukesh', 22, 'Chennai', 'India']
df
# Out:
#      Name  Age       City    Country
# a    jack   34     Sydeny  Australia
# b    Riti   30      Delhi      India
# c  Mukesh   22    Chennai      India
# d   Neelu   32  Bangalore      India
# e  Pravin   26       Pune      India
# f    Mike   17  las vegas         US
# g  Smriti   26  Bangalore      India

# %%
#Assignment: I want to add entries/rows in between the present data frame
# NOTE: I dont want to overwrite data

# %% [markdown]
# ## Addition of columns

# %%
df = df[:7]
df
# Out:
#      Name  Age       City    Country
# a    jack   34     Sydeny  Australia
# b    Riti   30      Delhi      India
# c  Mukesh   22    Chennai      India
# d   Neelu   32  Bangalore      India
# e  Pravin   26       Pune      India
# f    Mike   17  las vegas         US
# g  Smriti   26  Bangalore      India

# %%
df.shape
# Out:
# (7, 4)

# %%
# to add column use df[column_name] = [values]
df['Number']=[1,2,3,4,5,7,8]
# Out:
# C:\Users\hakim\AppData\Local\Temp/ipykernel_4032/885231787.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Number']=[1,2,3,4,5,7,8]

# %%
df
# Out:
#      Name  Age       City    Country  Number
# a    jack   34     Sydeny  Australia       1
# b    Riti   30      Delhi      India       2
# c  Mukesh   22    Chennai      India       3
# d   Neelu   32  Bangalore      India       4
# e  Pravin   26       Pune      India       5
# f    Mike   17  las vegas         US       7
# g  Smriti   26  Bangalore      India       8

# %%
import numpy as np
np.random.random(7)
# Out:
# array([0.05946776, 0.19545132, 0.48651496, 0.64740425, 0.86021131,
#        0.09222407, 0.71835066])

# %%
df['Random']=np.random.random(7)
# Out:
# C:\Users\hakim\AppData\Local\Temp/ipykernel_4032/308598842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Random']=np.random.random(7)

# %%
df
# Out:
#      Name  Age       City    Country  Number    Random
# a    jack   34     Sydeny  Australia       1  0.910779
# b    Riti   30      Delhi      India       2  0.120156
# c  Mukesh   22    Chennai      India       3  0.681626
# d   Neelu   32  Bangalore      India       4  0.305457
# e  Pravin   26       Pune      India       5  0.318658
# f    Mike   17  las vegas         US       7  0.241825
# g  Smriti   26  Bangalore      India       8  0.936251

# %%
df.loc[:,['New_col']] = [10,20,30,40,50,60,70]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
df
# Out:
#      Name  Age       City    Country  Number    Random  New_col
# a    jack   34     Sydeny  Australia       1  0.910779       10
# b    Riti   30      Delhi      India       2  0.120156       20
# c  Mukesh   22    Chennai      India       3  0.681626       30
# d   Neelu   32  Bangalore      India       4  0.305457       40
# e  Pravin   26       Pune      India       5  0.318658       50
# f    Mike   17  las vegas         US       7  0.241825       60
# g  Smriti   26  Bangalore      India       8  0.936251       70

# %%
# how to replace old values with new one
df.Number
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    7
# g    8
# Name: Number, dtype: int64

# %%
list(range(101,108))
# Out:
# [101, 102, 103, 104, 105, 106, 107]

# %%
df.Number = range(101,108)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df
# Out:
#      Name  Age       City    Country  Number    Random  New_col
# a    jack   34     Sydeny  Australia     101  0.910779       10
# b    Riti   30      Delhi      India     102  0.120156       20
# c  Mukesh   22    Chennai      India     103  0.681626       30
# d   Neelu   32  Bangalore      India     104  0.305457       40
# e  Pravin   26       Pune      India     105  0.318658       50
# f    Mike   17  las vegas         US     106  0.241825       60
# g  Smriti   26  Bangalore      India     107  0.936251       70

# %%
n = pd.Series(np.nan,index=range(7))
n
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# dtype: float64

# %%
df['NaN'] = n
# Out:
# C:\Users\hakim\AppData\Local\Temp/ipykernel_4032/397911752.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NaN'] = n

# %%
df
# Out:
#      Name  Age       City    Country  Number    Random  New_col  NaN
# a    jack   34     Sydeny  Australia     101  0.910779       10  NaN
# b    Riti   30      Delhi      India     102  0.120156       20  NaN
# c  Mukesh   22    Chennai      India     103  0.681626       30  NaN
# d   Neelu   32  Bangalore      India     104  0.305457       40  NaN
# e  Pravin   26       Pune      India     105  0.318658       50  NaN
# f    Mike   17  las vegas         US     106  0.241825       60  NaN
# g  Smriti   26  Bangalore      India     107  0.936251       70  NaN

# %%
#assignment:
# How to add column in between the dataFrame
# How to change name of column which is already present 
# Replace Smriti as Snehal
# Replace Bangalore by Maysor

# %% [markdown]
# ## Delete

# %%
df
# Out:
#      Name  Age       City    Country  Number    Random  New_col  NaN
# a    jack   34     Sydeny  Australia     101  0.910779       10  NaN
# b    Riti   30      Delhi      India     102  0.120156       20  NaN
# c  Mukesh   22    Chennai      India     103  0.681626       30  NaN
# d   Neelu   32  Bangalore      India     104  0.305457       40  NaN
# e  Pravin   26       Pune      India     105  0.318658       50  NaN
# f    Mike   17  las vegas         US     106  0.241825       60  NaN
# g  Smriti   26  Bangalore      India     107  0.936251       70  NaN

# %%
# suppose we want to delete a column
del df['Number']

# %%
df
# Out:
#      Name  Age       City    Country    Random  New_col  NaN
# a    jack   34     Sydeny  Australia  0.910779       10  NaN
# b    Riti   30      Delhi      India  0.120156       20  NaN
# c  Mukesh   22    Chennai      India  0.681626       30  NaN
# d   Neelu   32  Bangalore      India  0.305457       40  NaN
# e  Pravin   26       Pune      India  0.318658       50  NaN
# f    Mike   17  las vegas         US  0.241825       60  NaN
# g  Smriti   26  Bangalore      India  0.936251       70  NaN

# %%
del df['NaN']

# %%
df
# Out:
#      Name  Age       City    Country    Random  New_col
# a    jack   34     Sydeny  Australia  0.910779       10
# b    Riti   30      Delhi      India  0.120156       20
# c  Mukesh   22    Chennai      India  0.681626       30
# d   Neelu   32  Bangalore      India  0.305457       40
# e  Pravin   26       Pune      India  0.318658       50
# f    Mike   17  las vegas         US  0.241825       60
# g  Smriti   26  Bangalore      India  0.936251       70

# %%
del df.Random #not allowed use [] option
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4032/3867748249.py in <module>
# ----> 1 del df.Random
#
# AttributeError: Random

# %%
df.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4032/2782897641.py in <module>
# ----> 1 df.pop()
#
# TypeError: pop() missing 1 required positional argument: 'item'

# %%
#Return item and drop from frame. Raise KeyError if not found.
df.pop('Age')
# Out:
# a    34
# b    30
# c    22
# d    32
# e    26
# f    17
# g    26
# Name: Age, dtype: int64

# %%
df # df with no Age column
# Out:
#      Name       City    Country    Random  New_col
# a    jack     Sydeny  Australia  0.910779       10
# b    Riti      Delhi      India  0.120156       20
# c  Mukesh    Chennai      India  0.681626       30
# d   Neelu  Bangalore      India  0.305457       40
# e  Pravin       Pune      India  0.318658       50
# f    Mike  las vegas         US  0.241825       60
# g  Smriti  Bangalore      India  0.936251       70

# %%
# Assignments:
#How to delete a single row
#how to delete collection of rows
#how to delete random rows

# %%
df.Country['f'] = 'UK'
# Out:
# C:\Users\hakim\AppData\Local\Temp/ipykernel_4032/3302047950.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Country['f'] = 'UK'

# %%
df
# Out:
#      Name       City    Country    Random  New_col
# a    jack     Sydeny  Australia  0.910779       10
# b    Riti      Delhi      India  0.120156       20
# c  Mukesh    Chennai      India  0.681626       30
# d   Neelu  Bangalore      India  0.305457       40
# e  Pravin       Pune      India  0.318658       50
# f    Mike  las vegas         UK  0.241825       60
# g  Smriti  Bangalore      India  0.936251       70

# %%
df.Country = df.Country.replace(['UK'],'YK')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df
# Out:
#      Name       City    Country    Random  New_col
# a    jack     Sydeny  Australia  0.910779       10
# b    Riti      Delhi      India  0.120156       20
# c  Mukesh    Chennai      India  0.681626       30
# d   Neelu  Bangalore      India  0.305457       40
# e  Pravin       Pune      India  0.318658       50
# f    Mike  las vegas         YK  0.241825       60
# g  Smriti  Bangalore      India  0.936251       70

# %%
df.dtypes
# Out:
# Name        object
# City        object
# Country     object
# Random     float64
# New_col      int64
# dtype: object

# %%
df.Country.str.replace('YK','US')
# Out:
# a    Australia
# b        India
# c        India
# d        India
# e        India
# f           US
# g        India
# Name: Country, dtype: object

# %%
df.Country = df.Country.str.replace('YK','US')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df
# Out:
#      Name       City    Country    Random  New_col
# a    jack     Sydeny  Australia  0.910779       10
# b    Riti      Delhi      India  0.120156       20
# c  Mukesh    Chennai      India  0.681626       30
# d   Neelu  Bangalore      India  0.305457       40
# e  Pravin       Pune      India  0.318658       50
# f    Mike  las vegas         US  0.241825       60
# g  Smriti  Bangalore      India  0.936251       70
