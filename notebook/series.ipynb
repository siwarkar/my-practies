# %% [markdown]
# # Pandas

# %% [markdown]
# #### pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.

# %% [markdown]
# ### Pandas composed of 3 different data structures:
# - Series [1 Dim]
# - DataFrame [2 Dim]
# - Panel [N-Dim][Combo of series and DataFrame ]

# %% [markdown]
# # Series

# %%
import pandas

# %%
pandas.__version__
# Out:
# '1.3.4'

# %%
import pandas as pd
pd.__version__
# Out:
# '1.3.4'

# %%
# create an empty series
pd.Series()
# Out:
# C:\Users\hakim\AppData\Local\Temp/ipykernel_10024/3236373807.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pd.Series()
# Series([], dtype: float64)

# %%
pd.Series(dtype='object')
# object dtype means: u have str data/hetrogeneous data
# Out:
# Series([], dtype: object)

# %% [markdown]
# ## Strcuture of Series
# ### pd.Series(
#     data=None,
#     index=None,
#     dtype: 'Dtype | None' = None,
#     )

# %% [markdown]
# # Features of Series

# %%
# It is cobination of 3 things
- Data/values
- Index
- dtype

# %%
pd.Series([10,20,30,40,50])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
pd.Series(['10','20','30','40','50'])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: object

# %%
#Hetro data
pd.Series([10,20.88,'30','40','50'])
# Out:
# 0       10
# 1    20.88
# 2       30
# 3       40
# 4       50
# dtype: object

# %%
# It can accept homo. and hetro. data
# homo

# %%
# when we supply hetro. data or str data then dtype is object

# %%
# supply all str data
pd.Series(['Ramesh','Suresh','Dinesh'])
# Out:
# 0    Ramesh
# 1    Suresh
# 2    Dinesh
# dtype: object

# %%
# Difference between int32(4 bytes) and int64(8 bytes)
# 8 bit ==> 1 byte

# %%
a = pd.Series([10,20,30,40,50])
a
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
a.__sizeof__()
# Out:
# 168

# %%
b = pd.Series([10,20,30,40,50],dtype='int8')
b
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int8

# %%
b.__sizeof__()
# Out:
# 133

# %%
# background data structure is an array
a
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# indexing is possible
# access 40
a[3]
# Out:
# 40

# %%
a[4]
# Out:
# 50

# %%
a[-1] # in series -ve indexing is nt allowed
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10024/2857362791.py in <module>
# ----> 1 a[-1] # in series -ve indexing is nt allowed
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ...

# %%
# Is direct item assignment is possible??
a
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
a[2] #replace 30 by 300
# Out:
# 30

# %%
id(a)
# Out:
# 2153872382224

# %%
a[2] = 300

# %%
a
# Out:
# 0     10
# 1     20
# 2    300
# 3     40
# 4     50
# dtype: int64

# %%
id(a)
# Out:
# 2153872382224

# %%
pd.Series([12132312312332,123123454354646546546])
# Out:
# 0           12132312312332
# 1    123123454354646546546
# dtype: object

# %% [raw]
# # After the change,id doesnt change and changes persist in the same object
# # hence Series is a mutable data struture

# %%
# slicing supported
a[:]
# Out:
# 0     10
# 1     20
# 2    300
# 3     40
# 4     50
# dtype: int64

# %%
#access 300,40,50
a[2:]
# Out:
# 2    300
# 3     40
# 4     50
# dtype: int64

# %%
#10,300,50
a[::2]
# Out:
# 0     10
# 2    300
# 4     50
# dtype: int64

# %%
# replace 20,300,40 by 2,3,4 resp.
a[1:4]
# Out:
# 1     20
# 2    300
# 3     40
# dtype: int64

# %%
a[1:4] = [2,3,4]

# %%
a
# Out:
# 0    10
# 1     2
# 2     3
# 3     4
# 4    50
# dtype: int64

# %%
# replace 10 and 50 by 0
a[::4] = 0

# %%
a
# Out:
# 0    0
# 1    2
# 2    3
# 3    4
# 4    0
# dtype: int64

# %%
# if we want to add multiple values at same position then we cant add
a[0] = 1,2,3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#    1061         try:
# -> 1062             self._set_with_engine(key, value)
#    1063         except (KeyError, ValueError):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _set_with_engine(self, key, value)
#    1098         validate_numeric_casting(self.dtype, value)  # type: ignore[arg-type]
# -> 1099         self._values[loc] = value
#    1100
#
# ValueError: setting an array element with a sequence.
#
# ...

# %%
a[0] = [1,2,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#    1061         try:
# -> 1062             self._set_with_engine(key, value)
#    1063         except (KeyError, ValueError):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _set_with_engine(self, key, value)
#    1098         validate_numeric_casting(self.dtype, value)  # type: ignore[arg-type]
# -> 1099         self._values[loc] = value
#    1100
#
# ValueError: setting an array element with a sequence.
#
# ...

# %% [markdown]
# ### Manipulation of index

# %%
import numpy as np
s = pd.Series(np.arange(101,111))
s
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# 5    106
# 6    107
# 7    108
# 8    109
# 9    110
# dtype: int32

# %%
# if we wnt to access only data
s.values
#returns an array of value
# Out:
# array([101, 102, 103, 104, 105, 106, 107, 108, 109, 110])

# %%
# access index
s.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
# check dtype
s.dtype
# Out:
# dtype('int32')

# %%
# check dim
s.ndim
# Out:
# 1

# %%
#check total number of elements
s.size
# Out:
# 10

# %%
s.shape
# Out:
# (10,)

# %%
len(s)
# Out:
# 10

# %%
# now lets see Index manipulation
s = pd.Series(data=np.arange(101,111),index=range(10,20))
s
# Out:
# 10    101
# 11    102
# 12    103
# 13    104
# 14    105
# 15    106
# 16    107
# 17    108
# 18    109
# 19    110
# dtype: int32

# %%
s[10]
# Out:
# 101

# %%
s[19]
# Out:
# 110

# %%
s[17:]
# Out:
# Series([], dtype: int32)

# %%
s[7:]
# Out:
# 17    108
# 18    109
# 19    110
# dtype: int32

# %%
# scalar series: 10 customers with same bank_name
pd.Series('BOI',index=range(10))
# Out:
# 0    BOI
# 1    BOI
# 2    BOI
# 3    BOI
# 4    BOI
# 5    BOI
# 6    BOI
# 7    BOI
# 8    BOI
# 9    BOI
# dtype: object

# %%
nm = pd.Series('BOI',index=range(3))
nm
# Out:
# 0    BOI
# 1    BOI
# 2    BOI
# dtype: object

# %%
ac = pd.Series([12234,45646,67686])
ac
# Out:
# 0    12234
# 1    45646
# 2    67686
# dtype: int64

# %%
pd.DataFrame([ac,nm])
# Out:
#        0      1      2
# 0  12234  45646  67686
# 1    BOI    BOI    BOI

# %%
pd.concat([ac,nm],axis=1)
# Out:
#        0    1
# 0  12234  BOI
# 1  45646  BOI
# 2  67686  BOI

# %% [markdown]
# ## Lets create a series of a string and do the data analysis

# %%
n = pd.Series([])
n

# %% [markdown]
# #### to do analysis we need questions??

# %%
# fetch employee with inital letter P

# %%
# we can use boolean output as an input in index

# %%
# convert names in upper case

# %%
# sort in alphabatic order

# %%
#in descending order

# %%
# create a series which wil have length of each name
