# %% [markdown]
# # Introduction to Jupyter Notebook

# %% [markdown]
# ## Introduction to Jupyter Notebook

# %% [markdown]
# ### Introduction to Jupyter Notebook

# %% [markdown]
# #### Introduction to Jupyter Notebook

# %% [markdown]
# ##### Introduction to Jupyter Notebook

# %% [markdown]
# ###### Introduction to Jupyter Notebook

# %% [markdown]
# ####### Introduction to Jupyter Notebook

# %% [raw]
# Criteria
# 1. Gini index [default]
# 	1-sum(p(x))
#
# Gini split
# 	sum(gini(cat_i)*prob(cat_i))
# A feature for whome gini value is less will be selected as a root
# to expand further
#
# 2. Entropy
# 	- sum(p(x)logp(x))
#
# E(Weak) = -(p(weak/play)log(p(weak/play) - (p(weak/stay)log(p(weak/stay)
#
# Information gain
#  E(D/class) - (p(cate_i)*E(cat_i[play+stay])
#
# A feature for whose entropy value is max
#  will be selected as a root to expand further

# %% [markdown]
# Criteria
# 1. Gini index [default]
# 	1-sum(p(x))
#
# Gini split
# 	sum(gini(cat_i)*prob(cat_i))
# A feature for whome gini value is less will be selected as a root
# to expand further
#
# 2. Entropy
# 	- sum(p(x)logp(x))
#
# E(Weak) = -(p(weak/play)log(p(weak/play) - (p(weak/stay)log(p(weak/stay)
#
# Information gain
#  E(D/class) - (p(cate_i)*E(cat_i[play+stay])
#
# A feature for whose entropy value is max
#  will be selected as a root to expand further

# %% [markdown]
# Criteria
# 1. Gini index [default]
# 	1-sum(p(x))
#
# Gini split
# 	sum(gini(cat_i)*prob(cat_i))
# A feature for whome gini value is less will be selected as a root
# to expand further
#
# 2. Entropy
# 	- sum(p(x)logp(x))
#
# E(Weak) = -(p(weak/play)log(p(weak/play) - (p(weak/stay)log(p(weak/stay)
#
# Information gain
#  E(D/class) - (p(cate_i)*E(cat_i[play+stay])
#
# A feature for whose entropy value is max
#  will be selected as a root to expand further

# %%
# cell

# %%
print('hello5345')

# %%
for i in range(5):
    print(i)

# %%
print('hello')
