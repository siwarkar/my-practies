# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
f = pd.read_csv('fifa_eda.csv')
f.head(2)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
#
#            Club     Value   Wage Preferred Foot  International Reputation  \
# 0  FC Barcelona  110500.0  565.0           Left                       5.0
# 1      Juventus   77000.0  405.0          Right                       5.0
#
#    Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 0          4.0       RF    2004           2021-01-01  5.583333   159.0
# 1          5.0       ST    2018           2022-01-01  6.166667   183.0
#
#    Release Clause
# 0        226500.0
# 1        127100.0

# %%
data = f[['Age','Overall','Potential','Wage']]
plt.boxplot(data)
plt.show()

# %%
data = f[['Age','Overall','Potential']]
plt.boxplot(data)
plt.xticks(range(1,4),data.columns)
plt.show()
#
plt.boxplot(f.Wage)
plt.show()

# %%
Line plot
Scatter plot
Bar plor
Barh plot
Hist
Pie
Box plot

# %% [markdown]
# ## Subplot, Subplots

# %%
f.Wage.describe()
# Out:
# count    18207.000000
# mean         9.731312
# std         21.999290
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          9.000000
# max        565.000000
# Name: Wage, dtype: float64
