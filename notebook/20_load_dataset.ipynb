# %% [markdown]
# # Load Dataset

# %%
import pandas as pd

# %% [markdown]
# ### load txt file

# %%
pd.read_csv(r'C:\Users\hakim\OneDrive\Desktop\sample.txt')
# Out:
#   name  age  salary
# 0    A   23   34000
# 1    B   33   45000
# 2    C   45   78000

# %% [markdown]
# ### load a txt file without header

# %%
pd.read_csv(r'C:\Users\hakim\OneDrive\Desktop\sample_2.txt')
# Out:
#    A  23  34000
# 0  B  33  45000
# 1  C  45  78000

# %%
pd.read_csv(r'C:\Users\hakim\OneDrive\Desktop\sample_2.txt',header=None)
# Out:
#    0   1      2
# 0  A  23  34000
# 1  B  33  45000
# 2  C  45  78000

# %%
d = pd.read_csv(r'C:\Users\hakim\OneDrive\Desktop\sample_2.txt',header=None)
d
# Out:
#    0   1      2
# 0  A  23  34000
# 1  B  33  45000
# 2  C  45  78000

# %%
d.columns =['Name','Age','Salary']

# %%
d
# Out:
#   Name  Age  Salary
# 0    A   23   34000
# 1    B   33   45000
# 2    C   45   78000

# %% [markdown]
# ### load data with tab \t

# %%
pd.read_csv(r'C:\Users\hakim\OneDrive\Desktop\sample_3.txt')
# Out:
#   Name\tAge\tSalary
# 0      A\t23\t34000
# 1      B\t33\t45000
# 2      C\t45\t78000

# %%
pd.read_csv(r'C:\Users\hakim\OneDrive\Desktop\sample_3.txt',sep='\t')
# Out:
#   Name  Age  Salary
# 0    A   23   34000
# 1    B   33   45000
# 2    C   45   78000

# %% [markdown]
# ### load tsv(tab separated values) file

# %%
pd.read_csv(r'C:\Users\hakim\OneDrive\Desktop\sample_4.tsv',sep='\t')
# Out:
#   Name  Age  Salary
# 0    A   23   34000
# 1    B   33   45000
# 2    C   45   78000

# %% [markdown]
# ### load a file with \n

# %%
pd.read_csv(r'C:\Users\hakim\OneDrive\Desktop\sample_5.txt')
# Out:
#   name\nage\nsalary
# 0      A\n23\n34000
# 1      B\n33\n45000
# 2      C\n45\n78000

# %%
pd.read_csv(r'C:\Users\hakim\OneDrive\Desktop\sample_5.txt',sep='\n')
# Out:
#   name\nage\nsalary
# 0      A\n23\n34000
# 1      B\n33\n45000
# 2      C\n45\n78000

# %%
pd.read_csv(r'C:\Users\hakim\OneDrive\Desktop\sample.txt')
# Out:
#       A   23   34000
# 0  name  age  salary
# 1     B   33   45000
# 2     C   45   78000

# %%
pd.read_csv(r'C:\Users\hakim\OneDrive\Desktop\sample.txt',header=1)
# Out:
#   name  age  salary
# 0    B   33   45000
# 1    C   45   78000

# %% [markdown]
# ### load dataset from github

# %%
pd.read_csv('https://raw.githubusercontent.com/KeithGalli/disney-data-science-tasks/master/dataset/disney_movie_data_final.csv')
# Out:
#      Unnamed: 0                            title  \
# 0             0          Academy Award Review of
# 1             1  Snow White and the Seven Dwarfs
# 2             2                        Pinocchio
# 3             3                         Fantasia
# 4             4             The Reluctant Dragon
# ..          ...                              ...
# 427         427                             Soul
# 428         428         Raya and the Last Dragon
# 429         429                          Cruella
# 430         430                    Jungle Cruise
# 431         431            The Beatles: Get Back
#
#                                     Production company  \
# 0                              Walt Disney Productions
# 1                              Walt Disney Productions
# 2                              Walt Disney Productions
# 3                              Walt Disney Productions
# 4                              Walt Disney Productions
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/pomber/covid19/master/test/data/time_series_covid19_confirmed_global.csv')
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 240            NaN                  Libya  26.335100  17.228331        0
# 241            NaN     West Bank and Gaza  31.952200  35.233200        0
# 242            NaN          Guinea-Bissau  11.803700 -15.180400        0
# 243            NaN                   Mali  17.570692  -3.996166        0
# 244            NaN  Saint Kitts and Nevis  17.357822 -62.782998        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  3/16/20  3/17/20  \
# ...

# %% [raw]
# As disney dataset contains 400+ rows
# but if i want to read only 50 rows

# %%
pd.read_csv('https://raw.githubusercontent.com/KeithGalli/disney-data-science-tasks/master/dataset/disney_movie_data_final.csv',nrows=50)
# Out:
#     Unnamed: 0                                       title  \
# 0            0                     Academy Award Review of
# 1            1             Snow White and the Seven Dwarfs
# 2            2                                   Pinocchio
# 3            3                                    Fantasia
# 4            4                        The Reluctant Dragon
# 5            5                                       Dumbo
# 6            6                                       Bambi
# 7            7                              Saludos Amigos
# 8            8                   Victory Through Air Power
# 9            9                        The Three Caballeros
# 10          10                             Make Mine Music
# 11          11                           Song of the South
# 12          12                          Fun and Fancy Free
# 13          13                                 Melody Time
# 14          14                         So Dear to My Heart
# ...

# %% [raw]
# From disney dataset if specific columns we are interested to read

# %%
pd.read_csv('https://raw.githubusercontent.com/KeithGalli/disney-data-science-tasks/master/dataset/disney_movie_data_final.csv',
           usecols=['title','Country'])
# Out:
#                                title  \
# 0            Academy Award Review of
# 1    Snow White and the Seven Dwarfs
# 2                          Pinocchio
# 3                           Fantasia
# 4               The Reluctant Dragon
# ..                               ...
# 427                             Soul
# 428         Raya and the Last Dragon
# 429                          Cruella
# 430                    Jungle Cruise
# 431            The Beatles: Get Back
#
#                                                Country
# 0                                        United States
# 1                                        United States
# 2                                        United States
# 3                                        United States
# 4                                        United States
# ..                                                 ...
# 427                                      United States
# 428                                      United States
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/disney-data-science-tasks/master/dataset/disney_movie_data_final.csv',
           chunksize=100)
df

# %%
for i in df:
    print(i.shape)
# Out:
# (100, 32)
# (100, 32)
# (100, 32)
# (100, 32)
# (32, 32)

# %%
pd.read_csv(r'C:\Users\hakim\OneDrive\Desktop\sample_5.txt',delimiter="\n")
# Out:
#   name\nage\nsalary
# 0      A\n23\n34000
# 1      B\n33\n45000
# 2      C\n45\n78000
