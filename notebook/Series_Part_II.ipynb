# %%
import pandas as pd

# %%
# Create a series of names
s = pd.Series(['Aniket','Pratik','Pankaj','Geetanjali','Pratiksha','Amol','Sagar'])
s
# Out:
# 0        Aniket
# 1        Pratik
# 2        Pankaj
# 3    Geetanjali
# 4     Pratiksha
# 5          Amol
# 6         Sagar
# dtype: object

# %%
# check first 3 record
#s.head() #default it fetch 5 records
s.head(3)
# Out:
# 0    Aniket
# 1    Pratik
# 2    Pankaj
# dtype: object

# %%
s[:3]
# Out:
# 0    Aniket
# 1    Pratik
# 2    Pankaj
# dtype: object

# %%
# fetch last 2 record
s.tail(2)
# Out:
# 5     Amol
# 6    Sagar
# dtype: object

# %%
# plz sort the names in ascending order
s.sort_values()
# Out:
# 5          Amol
# 0        Aniket
# 3    Geetanjali
# 2        Pankaj
# 1        Pratik
# 4     Pratiksha
# 6         Sagar
# dtype: object

# %%
# in above case index is un ordered
s.sort_values(ignore_index=True)
# Out:
# 0          Amol
# 1        Aniket
# 2    Geetanjali
# 3        Pankaj
# 4        Pratik
# 5     Pratiksha
# 6         Sagar
# dtype: object

# %%
# if we want descending order
s.sort_values(ascending= False)
# Out:
# 6         Sagar
# 4     Pratiksha
# 1        Pratik
# 2        Pankaj
# 3    Geetanjali
# 0        Aniket
# 5          Amol
# dtype: object

# %%
# use sort_index()
srt = s.sort_values(ascending= False)
srt.sort_index()
# Out:
# 0        Aniket
# 1        Pratik
# 2        Pankaj
# 3    Geetanjali
# 4     Pratiksha
# 5          Amol
# 6         Sagar
# dtype: object

# %%
#index in descending order
srt.sort_index(ascending=False)
# Out:
# 6         Sagar
# 5          Amol
# 4     Pratiksha
# 3    Geetanjali
# 2        Pankaj
# 1        Pratik
# 0        Aniket
# dtype: object

# %%
srt.sort_index()
# Out:
# 0        Aniket
# 1        Pratik
# 2        Pankaj
# 3    Geetanjali
# 4     Pratiksha
# 5          Amol
# 6         Sagar
# dtype: object

# %%
srt
# Out:
# 6         Sagar
# 4     Pratiksha
# 1        Pratik
# 2        Pankaj
# 3    Geetanjali
# 0        Aniket
# 5          Amol
# dtype: object

# %%
srt.index
# Out:
# Int64Index([6, 4, 1, 2, 3, 0, 5], dtype='int64')

# %%
srt.index = [101,102,103,104,105,106,107]

# %%
srt
# Out:
# 101         Sagar
# 102     Pratiksha
# 103        Pratik
# 104        Pankaj
# 105    Geetanjali
# 106        Aniket
# 107          Amol
# dtype: object

# %%
srt.sort_values() #this is temp
# Out:
# 107          Amol
# 106        Aniket
# 105    Geetanjali
# 104        Pankaj
# 103        Pratik
# 102     Pratiksha
# 101         Sagar
# dtype: object

# %%
srt
# Out:
# 101         Sagar
# 102     Pratiksha
# 103        Pratik
# 104        Pankaj
# 105    Geetanjali
# 106        Aniket
# 107          Amol
# dtype: object

# %%
# permenant changes
srt.sort_values(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8196/3297549011.py in <module>
#       1 # permenant changes
# ----> 2 srt.sort_values(inplace=True)
#
# NameError: name 'srt' is not defined

# %%
srt
# Out:
# 107          Amol
# 106        Aniket
# 105    Geetanjali
# 104        Pankaj
# 103        Pratik
# 102     Pratiksha
# 101         Sagar
# dtype: object

# %%
srt.sort_index() #temp
# Out:
# 101         Sagar
# 102     Pratiksha
# 103        Pratik
# 104        Pankaj
# 105    Geetanjali
# 106        Aniket
# 107          Amol
# dtype: object

# %%
#perm.
srt.sort_index(inplace=True)

# %%
srt
# Out:
# 101         Sagar
# 102     Pratiksha
# 103        Pratik
# 104        Pankaj
# 105    Geetanjali
# 106        Aniket
# 107          Amol
# dtype: object

# %%
sd = pd.Series(['10',23.44,67.88])
sd
# Out:
# 0       10
# 1    23.44
# 2    67.88
# dtype: object

# %%
sd.sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1184/2267419174.py in <module>
# ----> 1 sd.sort_values()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3453         # GH 35922. Make sorting stable by leveraging nargsort
#    3454         values_to_sort = ensure_key_mapped(self, key)._values if key else self._values
# -> 3455         sorted_index = nargsort(values_to_sort, kind, bool(ascending), na_position)
#    3456
#    3457         result = self._constructor(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\sorting.py in nargsort(items, kind, ascending, na_position, key, mask)
#     401         non_nans = non_nans[::-1]
#     402         non_nan_idx = non_nan_idx[::-1]
# --> 403     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     404     if not ascending:
#     405         indexer = indexer[::-1]
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
#check different methods/properties supported by series
srt
# Out:
# 101         Sagar
# 102     Pratiksha
# 103        Pratik
# 104        Pankaj
# 105    Geetanjali
# 106        Aniket
# 107          Amol
# dtype: object

# %%
srt.ndim
# Out:
# 1

# %%
srt.size
# Out:
# 7

# %%
srt.index
# Out:
# Int64Index([101, 102, 103, 104, 105, 106, 107], dtype='int64')

# %%
srt.values
# Out:
# array(['Sagar', 'Pratiksha', 'Pratik', 'Pankaj', 'Geetanjali', 'Aniket',
#        'Amol'], dtype=object)

# %%
srt.to_dict()
# Out:
# {101: 'Sagar',
#  102: 'Pratiksha',
#  103: 'Pratik',
#  104: 'Pankaj',
#  105: 'Geetanjali',
#  106: 'Aniket',
#  107: 'Amol'}

# %%
print(dir(srt))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_REVERSED', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__array_wrap__', '__bool__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__weakref__', '__xor__', '_accessors', '_accum_func', '_add_numeric_operations', '_agg_by_level', '_agg_examples_doc', '_agg_see_also_doc', '_align_frame', '_align_series', '_arith_method', '_as_manager', '_attrs', '_binop', '_can_hold_na', '_check_inplace_and_allows_duplicate_labels', '_check_inplace_setting', '_check_is_chained_assignment_possible', '_check_label_or_level_ambiguity', '_check_setitem_copy', '_clear_item_cache', '_clip_with_one_bound', '_clip_with_scalar', '_cmp_method', '_consolidate', '_consolidate_inplace', '_construct_axes_dict', '_construct_axes_from_arguments', '_construct_result', '_constructor', '_constructor_expanddim', '_convert', '_convert_dtypes', '_data', '_dir_additions', '_dir_deletions', '_drop_axis', '_drop_labels_or_levels', '_duplicated', '_find_valid_index', '_flags', '_from_mgr', '_get_axis', '_get_axis_name', '_get_axis_number', '_get_axis_resolvers', '_get_block_manager_axis', '_get_bool_data', '_get_cacher', '_get_cleaned_column_resolvers', '_get_index_resolvers', '_get_label_or_level_values', '_get_numeric_data', '_get_value', '_get_values', '_get_values_tuple', '_get_with', '_gotitem', '_hidden_attrs', '_index', '_indexed_same', '_info_axis', '_info_axis_name', '_info_axis_number', '_init_dict', '_init_mgr', '_inplace_method', '_internal_names', '_internal_names_set', '_is_cached', '_is_copy', '_is_label_or_level_reference', '_is_label_reference', '_is_level_reference', '_is_mixed_type', '_is_view', '_item_cache', '_ixs', '_logical_func', '_logical_method', '_map_values', '_maybe_update_cacher', '_memory_usage', '_metadata', '_mgr', '_min_count_stat_function', '_name', '_needs_reindex_multi', '_protect_consolidate', '_reduce', '_reindex_axes', '_reindex_indexer', '_reindex_multi', '_reindex_with_indexers', '_replace_single', '_repr_data_resource_', '_repr_latex_', '_reset_cache', '_reset_cacher', '_set_as_cached', '_set_axis', '_set_axis_name', '_set_axis_nocheck', '_set_is_copy', '_set_labels', '_set_name', '_set_value', '_set_values', '_set_with', '_set_with_engine', '_slice', '_stat_axis', '_stat_axis_name', '_stat_axis_number', '_stat_function', '_stat_function_ddof', '_take_with_is_copy', '_typ', '_update_inplace', '_validate_dtype', '_values', '_where', 'abs', 'add', 'add_prefix', 'add_suffix', 'agg', 'aggregate', 'align', 'all', 'any', 'append', 'apply', 'argmax', 'argmin', 'argsort', 'array', 'asfreq', 'asof', 'astype', 'at', 'at_time', 'attrs', 'autocorr', 'axes', 'backfill', 'between', 'between_time', 'bfill', 'bool', 'clip', 'combine', 'combine_first', 'compare', 'convert_dtypes', 'copy', 'corr', 'count', 'cov', 'cummax', 'cummin', 'cumprod', 'cumsum', 'describe', 'diff', 'div', 'divide', 'divmod', 'dot', 'drop', 'drop_duplicates', 'droplevel', 'dropna', 'dtype', ...

# %%
srt.to_numpy()
# Out:
# array(['Sagar', 'Pratiksha', 'Pratik', 'Pankaj', 'Geetanjali', 'Aniket',
#        'Amol'], dtype=object)

# %%
srt.values
# Out:
# array(['Sagar', 'Pratiksha', 'Pratik', 'Pankaj', 'Geetanjali', 'Aniket',
#        'Amol'], dtype=object)

# %%
srt.ndim
# Out:
# 1

# %%
# convert series to csv file
srt.to_csv(r'C:\Users\hakim\OneDrive\Desktop\New folder\data.csv',index=False,
          header=False)

# %%
srt.to_csv('batch_20.csv')

# %%
# create another series of names
s2 = pd.Series(['Pravin','Akshay','Ayesha'])
s2
# Out:
# 0    Pravin
# 1    Akshay
# 2    Ayesha
# dtype: object

# %%
srt
# Out:
# 101         Sagar
# 102     Pratiksha
# 103        Pratik
# 104        Pankaj
# 105    Geetanjali
# 106        Aniket
# 107          Amol
# dtype: object

# %%
# lets combine series using append
srt.append(s2)
# Out:
# 101         Sagar
# 102     Pratiksha
# 103        Pratik
# 104        Pankaj
# 105    Geetanjali
# 106        Aniket
# 107          Amol
# 0          Pravin
# 1          Akshay
# 2          Ayesha
# dtype: object

# %%
# to make proper indexing use ignore_index
srt.append(s2,ignore_index=True)
# Out:
# 0         Sagar
# 1     Pratiksha
# 2        Pratik
# 3        Pankaj
# 4    Geetanjali
# 5        Aniket
# 6          Amol
# 7        Pravin
# 8        Akshay
# 9        Ayesha
# dtype: object

# %%
srt2 = srt.append(s2)
srt2
# Out:
# 101         Sagar
# 102     Pratiksha
# 103        Pratik
# 104        Pankaj
# 105    Geetanjali
# 106        Aniket
# 107          Amol
# 0          Pravin
# 1          Akshay
# 2          Ayesha
# dtype: object

# %%
srt2.sort_index(ignore_index=True,inplace=True)

# %%
srt2
# Out:
# 0        Pravin
# 1        Akshay
# 2        Ayesha
# 3         Sagar
# 4     Pratiksha
# 5        Pratik
# 6        Pankaj
# 7    Geetanjali
# 8        Aniket
# 9          Amol
# dtype: object

# %%
srt3 = srt.append(s2)
srt3
# Out:
# 101         Sagar
# 102     Pratiksha
# 103        Pratik
# 104        Pankaj
# 105    Geetanjali
# 106        Aniket
# 107          Amol
# 0          Pravin
# 1          Akshay
# 2          Ayesha
# dtype: object

# %%
srt3.reset_index()
# Out:
#    index           0
# 0    101       Sagar
# 1    102   Pratiksha
# 2    103      Pratik
# 3    104      Pankaj
# 4    105  Geetanjali
# 5    106      Aniket
# 6    107        Amol
# 7      0      Pravin
# 8      1      Akshay
# 9      2      Ayesha

# %%
type(srt3.reset_index())
# Out:
# pandas.core.frame.DataFrame

# %%
type(srt3)
# Out:
# pandas.core.series.Series

# %%
# i dont want index column--> it gives Series
srt3.reset_index(drop=True)
# Out:
# 0         Sagar
# 1     Pratiksha
# 2        Pratik
# 3        Pankaj
# 4    Geetanjali
# 5        Aniket
# 6          Amol
# 7        Pravin
# 8        Akshay
# 9        Ayesha
# dtype: object

# %%
#perm. changes
srt3.reset_index(drop=True,inplace=True)

# %%
srt3
# Out:
# 0         Sagar
# 1     Pratiksha
# 2        Pratik
# 3        Pankaj
# 4    Geetanjali
# 5        Aniket
# 6          Amol
# 7        Pravin
# 8        Akshay
# 9        Ayesha
# dtype: object

# %%
# apply() Invoke function on values of Series.
# check length of each name
#syntax: apply(function_name)
srt3.apply(len)
# Out:
# 0     5
# 1     9
# 2     6
# 3     6
# 4    10
# 5     6
# 6     4
# 7     6
# 8     6
# 9     6
# dtype: int64

# %%
list(map(len,srt3))
# Out:
# [5, 9, 6, 6, 10, 6, 4, 6, 6, 6]

# %%
# convert all names in upper case
srt3.apply(str.upper)
# Out:
# 0         SAGAR
# 1     PRATIKSHA
# 2        PRATIK
# 3        PANKAJ
# 4    GEETANJALI
# 5        ANIKET
# 6          AMOL
# 7        PRAVIN
# 8        AKSHAY
# 9        AYESHA
# dtype: object

# %%
# add some constant str at the end
# example: Amit Punekar
fn = lambda nm:nm+' Punekar'
srt3.apply(fn)
# Out:
# 0         Sagar Punekar
# 1     Pratiksha Punekar
# 2        Pratik Punekar
# 3        Pankaj Punekar
# 4    Geetanjali Punekar
# 5        Aniket Punekar
# 6          Amol Punekar
# 7        Pravin Punekar
# 8        Akshay Punekar
# 9        Ayesha Punekar
# dtype: object

# %%
srt3[6] = 'Mr Amol'

# %%
srt3
# Out:
# 0         Sagar
# 1     Pratiksha
# 2        Pratik
# 3        Pankaj
# 4    Geetanjali
# 5        Aniket
# 6       Mr Amol
# 7        Pravin
# 8        Akshay
# 9        Ayesha
# dtype: object

# %%
# findout people name ending with a
srt3[srt3.str.endswith('a')]
# Out:
# 1    Pratiksha
# 9       Ayesha
# dtype: object

# %%
def find(nm):
    if nm.endswith('a')== True:
        return nm
srt3.apply(find)
# Out:
# 0         None
# 1    Pratiksha
# 2         None
# 3         None
# 4         None
# 5         None
# 6         None
# 7         None
# 8         None
# 9       Ayesha
# dtype: object

# %%
#using filter
list(filter(find,srt3))
# Out:
# ['Pratiksha', 'Ayesha']

# %%
#fetch name with length of name > 6
srt3[srt3.apply(len)>6]
# Out:
# 1     Pratiksha
# 4    Geetanjali
# 6       Mr Amol
# dtype: object

# %%
# reverse each name within the string
#srt3[::-1]
rev = lambda nm:nm[::-1]
srt3.apply(rev)
# Out:
# 0         ragaS
# 1     ahskitarP
# 2        kitarP
# 3        jaknaP
# 4    ilajnateeG
# 5        tekinA
# 6       lomA rM
# 7        nivarP
# 8        yahskA
# 9        ahseyA
# dtype: object

# %%
x = reversed('sagar')
list(x)
''.join(x)
# Out:
# ''

# %%
#access alternate name
srt3[::2]
# Out:
# 0         Sagar
# 2        Pratik
# 4    Geetanjali
# 6       Mr Amol
# 8        Akshay
# dtype: object

# %%
srt3
# Out:
# 0         Sagar
# 1     Pratiksha
# 2        Pratik
# 3        Pankaj
# 4    Geetanjali
# 5        Aniket
# 6       Mr Amol
# 7        Pravin
# 8        Akshay
# 9        Ayesha
# dtype: object
