# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Pair plotting

# %%
# it works on numeric column
# it form a matrix, where we can identify how each feature is corelated with each other
# and with itself
sns.pairplot(data= df)

# %%
n = df[['sepal_length','petal_length','species']]
sns.pairplot(data=n,hue='species')

# %% [markdown]
# **Categorical Plotting**
#
# When one or both the variables under study are categorical, we use plots like stripplot(), swarmplot(), etc,.

# %%
# Categorical Scatter plots
#stripplot()
#stripplot() is used when one of the variable under study is categorical. 
#It represents the data in sorted order along any one of the axis.

# %%
#load penguin dataset
p = sns.load_dataset('penguins')
p.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
#check unique island
p.island.unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
#check unique species
p.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
#check unique gender
p.sex.unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
#check columns
p.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
p.shape
# Out:
# (344, 7)

# %% [markdown]
# # stripplot()

# %%
#Draw a scatterplot where one variable is categorical.
# On the basis of Species differentiate with respect to body mass
# Species vs body_mass
sns.stripplot(x='species',y='body_mass_g',data=p)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
p.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
# in above plot i want to see genderwise distribustion
sns.stripplot(x='sex',y='body_mass_g',data=p)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='body_mass_g'>

# %% [markdown]
# Findings:
#     Male's are havinf more entries than female , Male body mass is greater than Female

# %%
# hue=species
sns.stripplot(x='sex',y='body_mass_g',data=p,hue='species')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='body_mass_g'>

# %%
p.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
#bill length
sns.stripplot(x='species',y='bill_length_mm',data=p)
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %%
#load tips dataset as t
t = sns.load_dataset('tips')
t.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#select categorical columns
t.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
t.select_dtypes(include='category')
# Out:
#         sex smoker   day    time
# 0    Female     No   Sun  Dinner
# 1      Male     No   Sun  Dinner
# 2      Male     No   Sun  Dinner
# 3      Male     No   Sun  Dinner
# 4    Female     No   Sun  Dinner
# ..      ...    ...   ...     ...
# 239    Male     No   Sat  Dinner
# 240  Female    Yes   Sat  Dinner
# 241    Male    Yes   Sat  Dinner
# 242    Male     No   Sat  Dinner
# 243  Female     No  Thur  Dinner
#
# [244 rows x 4 columns]

# %%
# check scatter plot with genderwise tip
sns.stripplot(x='sex',y='tip',data=t)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
#genderwise total_bill
sns.stripplot(x='sex',y='total_bill',data=t)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
#time vs total_bill hue='sex'
print(t.time.unique())
sns.stripplot(x='time',y='total_bill',data=t,hue='sex',palette='Set2')
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %% [markdown]
# **Distribution plots**
#
# Performing comparison within categories.

# %% [markdown]
# ## Box Plots
# #Boxplot is a convenient way to visualize the distribution of data through their quartiles.

# %%
#check unique days
t.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=t)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='total_bill',data=t)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.boxplot(data=t)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='day',y='total_bill',data=t)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='time',y='total_bill',data=t,hue='smoker',palette='Reds')
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
#set title('Box plot for Day vs total bill')

# %%
#boxplot using matplotlib

# %% [markdown]
# ## Bar Plot
# - The barplot() shows the relation between a categorical variable and a continuous variable.
# - The data is represented in rectangular bars where the length the bar represents the proportion of the data in that category.

# %%
#load titanic data
ti = sns.load_dataset('titanic')
ti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# check survival rate with respect to gender
sns.barplot(x='sex',y='survived',data=ti)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
#hue=class
sns.barplot(x='sex',y='survived',data=ti,hue='class')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
# embarked vs survived
sns.barplot(x='embarked',y='survived',data=ti)
# Out:
# <AxesSubplot:xlabel='embarked', ylabel='survived'>

# %%
df
sns.barplot(x='species',y='sepal_width',data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
col = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
for i in col:
    sns.barplot(x='species',y=i,data=df)
    plt.show()

# %% [markdown]
# ## count plot
# - A special case in barplot is to show the no of observations in each category rather than
# - computing a statistic for a second variable. For this, we use countplot()

# %%
#use titanic dataset
ti[:2]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
#check classwise count
sns.countplot(ti['class'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(x='class',data=ti)
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
ti['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
sns.countplot(x='sex',data=ti)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='sex',data=ti,hue='class')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#hue=class

# %% [markdown]
# By observing the above result,we can conclude, more male parrengers present than female.
# More specifically, in third class category we have more male candidates
# Female are less in count but their survival rate is too high.

# %%
#Violine plot: combination of KDE + Box plot
sns.violinplot(x='class',y='fare',data=ti)
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
sns.violinplot(x='sepal_length',data=df)
# Out:
# <AxesSubplot:xlabel='sepal_length'>

# %%
sns.violinplot(x='class',y='age',data=ti,hue='sex',palette='cubehelix')
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
# Assignment: sex vs age

# %% [markdown]
# # heatmap

# %%
# when we want to show matrix representation with respect to 
# weight of the each feature
# then go with heatmap

# %%
dsc = df.describe()
dsc
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.heatmap(dsc,annot=True)
# Out:
# <AxesSubplot:>

# %%
#correlation: give correlation between 2 features +ve or negative -ve
cr =df.corr()
cr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
plt.scatter(df.sepal_length,df.petal_length)

# %%
sns.heatmap(cr,annot=True,cmap='Set1')
# Out:
# <AxesSubplot:>

# %%
# correlation style
cr.style.background_gradient(cmap='gist_earth')
# Out:
# <style type="text/css">
# #T_0cc68_row0_col0, #T_0cc68_row1_col1, #T_0cc68_row2_col2, #T_0cc68_row3_col3 {
#   background-color: #fdfbfb;
#   color: #000000;
# }
# #T_0cc68_row0_col1 {
#   background-color: #25657d;
#   color: #f1f1f1;
# }
# #T_0cc68_row0_col2 {
#   background-color: #e4c5b9;
#   color: #000000;
# }
# #T_0cc68_row0_col3 {
#   background-color: #d7b298;
#   color: #000000;
# }
# #T_0cc68_row1_col0, #T_0cc68_row1_col2, #T_0cc68_row1_col3, #T_0cc68_row2_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_0cc68_row2_col0 {
#   background-color: #ddb9a5;
#   color: #000000;
# }
# #T_0cc68_row2_col3, #T_0cc68_row3_col2 {
#   background-color: #f6eae9;
#   color: #000000;
# }
# #T_0cc68_row3_col0 {
#   background-color: #cfac87;
#   color: #000000;
# }
# #T_0cc68_row3_col1 {
#   background-color: #070975;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0cc68_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >sepal_length</th>
#       <th class="col_heading level0 col1" >sepal_width</th>
#       <th class="col_heading level0 col2" >petal_length</th>
#       <th class="col_heading level0 col3" >petal_width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cc68_level0_row0" class="row_heading level0 row0" >sepal_length</th>
#       <td id="T_0cc68_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0cc68_row0_col1" class="data row0 col1" >-0.117570</td>
#       <td id="T_0cc68_row0_col2" class="data row0 col2" >0.871754</td>
#       <td id="T_0cc68_row0_col3" class="data row0 col3" >0.817941</td>
#     </tr>
#     <tr>
#       <th id="T_0cc68_level0_row1" class="row_heading level0 row1" >sepal_width</th>
#       <td id="T_0cc68_row1_col0" class="data row1 col0" >-0.117570</td>
#       <td id="T_0cc68_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0cc68_row1_col2" class="data row1 col2" >-0.428440</td>
#       <td id="T_0cc68_row1_col3" class="data row1 col3" >-0.366126</td>
#     </tr>
#     <tr>
#       <th id="T_0cc68_level0_row2" class="row_heading level0 row2" >petal_length</th>
#       <td id="T_0cc68_row2_col0" class="data row2 col0" >0.871754</td>
#       <td id="T_0cc68_row2_col1" class="data row2 col1" >-0.428440</td>
#       <td id="T_0cc68_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0cc68_row2_col3" class="data row2 col3" >0.962865</td>
#     </tr>
#     <tr>
#       <th id="T_0cc68_level0_row3" class="row_heading level0 row3" >petal_width</th>
#       <td id="T_0cc68_row3_col0" class="data row3 col0" >0.817941</td>
#       <td id="T_0cc68_row3_col1" class="data row3 col1" >-0.366126</td>
#       <td id="T_0cc68_row3_col2" class="data row3 col2" >0.962865</td>
#       <td id="T_0cc68_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#check corr of few columns

# %%
#heatmap
